# %%
import pandas as pd

file_path = "/Users/sigmanationn/Desktop/Analysis Project/Group Project 1/games.csv"

df = pd.read_csv(file_path)

print(df.head(50))
# Out:
#     Unnamed: 0                                    Title  Release Date  \
# 0            0                               Elden Ring  Feb 25, 2022
# 1            1                                    Hades  Dec 10, 2019
# 2            2  The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3            3                                Undertale  Sep 15, 2015
# 4            4                            Hollow Knight  Feb 24, 2017
# 5            5                                Minecraft  Nov 18, 2011
# 6            6                                    Omori  Dec 25, 2020
# 7            7                            Metroid Dread  Oct 07, 2021
# 8            8                                 Among Us  Jun 15, 2018
# 9            9                           NieR: Automata  Feb 23, 2017
# 10          10                          Persona 5 Royal  Oct 31, 2019
# 11          11                                    Stray  Jul 19, 2022
# ...

# %%
# I LISTED ALL THE COLUMSN IN MY CSV TO GET AN OVERVIEW

columns_list = df.columns.tolist()

print(columns_list)
# Out:
# ['Unnamed: 0', 'Title', 'Release Date', 'Team', 'Rating', 'Times Listed', 'Number of Reviews', 'Genres', 'Summary', 'Reviews', 'Plays', 'Playing', 'Backlogs', 'Wishlist']

# %%
# LISTED A GENERAL OVERVIEW OF ALL MY COLUMNS 

df = pd.read_csv((file_path), usecols=['Title', 'Release Date', 'Team', 'Rating', 'Number of Reviews', 'Genres', 'Reviews','Plays',])

print(df)
# Out:
#                                         Title  Release Date  \
# 0                                  Elden Ring  Feb 25, 2022
# 1                                       Hades  Dec 10, 2019
# 2     The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 3                                   Undertale  Sep 15, 2015
# 4                               Hollow Knight  Feb 24, 2017
# ...                                       ...           ...
# 1507             Back to the Future: The Game  Dec 22, 2010
# 1508                        Team Sonic Racing  May 21, 2019
# 1509                           Dragon's Dogma  May 22, 2012
# 1510                          Baldur's Gate 3  Oct 06, 2020
# 1511                 The LEGO Movie Videogame  Feb 04, 2014
#
#                                                    Team  Rating  \
# 0        ['Bandai Namco Entertainment', 'FromSoftware']     4.5
# 1                                  ['Supergiant Games']     4.3
# ...

# %%
# HIGHEST RATED VIDEO GAMES OF ALL TIME 
# AND THE RELEASE DATE


df = pd.read_csv((file_path), usecols=['Title','Rating', 'Release Date'])

df_sorted_Rating = df.sort_values(by='Rating', ascending=False)




print(df_sorted_Rating.head(20))
# Out:
#                                            Title     Release Date  Rating
# 1252           Elden Ring: Shadow of the Erdtree  releases on TBD     4.8
# 28                  Disco Elysium: The Final Cut     May 01, 2020     4.6
# 1035                 Bloodborne: The Old Hunters     Nov 24, 2015     4.6
# 539                 Umineko: When They Cry Chiru     Sep 15, 2009     4.6
# 369                                  Outer Wilds     May 28, 2019     4.6
# 354                 Disco Elysium: The Final Cut     May 01, 2020     4.6
# 43                                   Outer Wilds     May 28, 2019     4.6
# 717                Hitman World of Assassination     Jan 26, 2023     4.6
# 297                  Bloodborne: The Old Hunters     Nov 24, 2015     4.6
# 804                 Disco Elysium: The Final Cut     May 01, 2020     4.6
# 819                                  Outer Wilds     May 28, 2019     4.6
# 252                 Umineko: When They Cry Chiru     Sep 15, 2009     4.6
# ...

# %%
# HIGHEST RATED VIDEO GAMES OF ALL TIME 
# AND THE RELEASE DATE
# DATES THAT HAD THE MOST HIGHEST RATED RELEASES


df = pd.read_csv((file_path), usecols=['Title','Rating', 'Release Date'])

df_sorted_Rating = df.sort_values(by='Rating', ascending=False)

name_counts0 = df_sorted_Rating['Release Date'].value_counts()



print(name_counts0.head(500))
# Out:
# Nov 12, 2020    8
# Nov 19, 2006    7
# Jun 16, 2022    6
# Sep 10, 2021    5
# Nov 13, 2007    5
#                ..
# May 02, 2017    1
# May 25, 2017    1
# Feb 05, 2013    1
# Feb 14, 2023    1
# Sep 29, 2022    1
# Name: Release Date, Length: 500, dtype: int64

# %%
# HIGHEST RATED VIDEO GAMES OF ALL TIME 
# TEAMS THAT BUILD THE VIDEO GAMES


df = pd.read_csv((file_path), usecols=['Rating','Title','Team'])

df_sorted_Rating = df.sort_values(by='Rating', ascending=False)


print(df_sorted_Rating.head(20))
# Out:
#                                            Title  \
# 1252           Elden Ring: Shadow of the Erdtree
# 28                  Disco Elysium: The Final Cut
# 1035                 Bloodborne: The Old Hunters
# 539                 Umineko: When They Cry Chiru
# 369                                  Outer Wilds
# 354                 Disco Elysium: The Final Cut
# 43                                   Outer Wilds
# 717                Hitman World of Assassination
# 297                  Bloodborne: The Old Hunters
# 804                 Disco Elysium: The Final Cut
# 819                                  Outer Wilds
# 252                 Umineko: When They Cry Chiru
# 894                                Disco Elysium
# 428                                Disco Elysium
# 991              Metal Gear Solid 3: Subsistence
# 957                 Final Fantasy XIV: Endwalker
# 1198  Metal Gear Solid 3: Snake Eater HD Edition
# 1090           The Great Ace Attorney 2: Resolve
# ...

# %%
# HIGHEST RATED VIDEO GAMES OF ALL TIME 
# TEAMS THAT BUILD THE VIDEO GAMES
# TEAMS THAT BUILD THE MOST FAMOUS GAMES CONSISTENTALY


df = pd.read_csv((file_path), usecols=['Rating','Title','Team'])

df_sorted_Rating = df.sort_values(by='Rating', ascending=False)

name_counts1 = df_sorted_Rating['Team'].value_counts()


print(name_counts1.head(5))
# Out:
# ['Capcom']                      35
# ['Square Enix']                 31
# ['Nintendo']                    19
# ['Nintendo', 'Game Freak']      19
# ['Nintendo', 'Nintendo EAD']    19
# Name: Team, dtype: int64

# %%
# HIGHEST RATED VIDEO GAMES OF ALL TIME 
# GENRES 



df = pd.read_csv((file_path), usecols=['Rating','Title','Genres'])

df_sorted_Rating = df.sort_values(by='Rating', ascending=False)


print(df_sorted_Rating.head(20))
# Out:
#                                            Title  Rating  \
# 1252           Elden Ring: Shadow of the Erdtree     4.8
# 28                  Disco Elysium: The Final Cut     4.6
# 1035                 Bloodborne: The Old Hunters     4.6
# 539                 Umineko: When They Cry Chiru     4.6
# 369                                  Outer Wilds     4.6
# 354                 Disco Elysium: The Final Cut     4.6
# 43                                   Outer Wilds     4.6
# 717                Hitman World of Assassination     4.6
# 297                  Bloodborne: The Old Hunters     4.6
# 804                 Disco Elysium: The Final Cut     4.6
# 819                                  Outer Wilds     4.6
# 252                 Umineko: When They Cry Chiru     4.6
# 894                                Disco Elysium     4.6
# 428                                Disco Elysium     4.6
# 991              Metal Gear Solid 3: Subsistence     4.6
# ...

# %%
# HIGHEST RATED VIDEO GAMES OF ALL TIME 
# GENRES 
# THE MOST COMMON GENRES 



df = pd.read_csv((file_path), usecols=['Rating','Title','Genres'])

df_sorted_Rating = df.sort_values(by='Rating', ascending=False)

name_counts = df_sorted_Rating['Genres'].value_counts()




print(name_counts.head(20))
# Out:
# ['Adventure', 'RPG']                           154
# ['Adventure', 'Platform']                      107
# ['Adventure', 'Shooter']                        82
# ['Shooter']                                     72
# ['Adventure', 'RPG', 'Turn Based Strategy']     48
# ['Adventure']                                   44
# ['Adventure', 'Brawler']                        40
# ['RPG']                                         37
# ['Adventure', 'RPG', 'Shooter']                 34
# ['Platform']                                    34
# ['Fighting']                                    30
# ['Adventure', 'Platform', 'Shooter']            29
# ['Adventure', 'Indie']                          27
# ['Adventure', 'Indie', 'Platform']              26
# ['Adventure', 'Puzzle']                         25
# ['Adventure', 'Brawler', 'RPG']                 22
# ['RPG', 'Shooter']                              21
# ['Adventure', 'Platform', 'Puzzle']             20
# ...
